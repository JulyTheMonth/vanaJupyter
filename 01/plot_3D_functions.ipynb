# %% [markdown]
# <a href="https://colab.research.google.com/github/JulyTheMonth/vanaJupyter/blob/main/01/plot_3D_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plot a 3D function in Python

# %% [markdown]
# Test

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


## for high resolution image
# %config InlineBackend.figure_format = 'retina'

# Define the function f(x,y) = z
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

# Create a meshgrid of x and y values
x = np.linspace(-1, 1, 50)
y = np.linspace(-1, 1, 50)
X, Y = np.meshgrid(x, y)

# Evaluate the function f(x,y) at each point on the meshgrid
Z = f(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Set the colormap to 'coolwarm' (or any other colormap you like)
colormap = plt.cm.coolwarm

# Plot the surface with the colorscale determined by z values
surface = ax.plot_surface(X, Y, Z, cmap=colormap)

# Add a colorbar to the plot
fig.colorbar(surface, shrink=0.5, aspect=5)

# Set the axis labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# Show the plot
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# draw sphere
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color="k")

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


## for high resolution image
# %config InlineBackend.figure_format = 'retina'

# Define the function f(x,y) = z
def f(x, y, c=1):
    res = -x*x - y*y + c
    res[res<0] = 0
    return res

# Create a meshgrid of x and y values
x = np.linspace(-1, 1, 50)
y = np.linspace(-1, 1, 50)
X, Y = np.meshgrid(x, y)

# Evaluate the function f(x,y) at each point on the meshgrid
Z = f(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Set the colormap to 'coolwarm' (or any other colormap you like)
colormap = plt.cm.coolwarm

# Plot the surface with the colorscale determined by z values
surface = ax.plot_surface(X, Y, Z, cmap=colormap)

# Add a colorbar to the plot
fig.colorbar(surface, shrink=0.5, aspect=5)

# Set the axis labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# Show the plot
plt.show()

# %% [markdown]
# ## Visualize Gradient Field

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm


## for high resolution image
# %config InlineBackend.figure_format = 'retina'


def plot_function(f, x, y, x_range, y_range):
    """ takes a sympy function f(x,y) and plots it over the range x_range and y_range """
    f = sp.lambdify((x, y), f, 'numpy')
    X, Y = np.meshgrid(x_range, y_range)
    Z = f(X, Y)

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
    ax.set_title("Funktionsgraph")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    return ax




def plot_gradient_vector_field(f, x, y, x_range, y_range):
    """ takes a sympy function f(x,y) and plots the gradient of f over the range x_range and y_range """
    X, Y = np.meshgrid(x_range, y_range)
    grad_fx, grad_fy = [sp.lambdify((x,y),f.diff(xi),"numpy") for xi in [x,y]]
    u = grad_fx(X, Y)
    v = grad_fy(X, Y)

    plt.figure()
    plt.quiver(X, Y, u, v)
    plt.title("Gradientenfeld")
    plt.xlabel("x")
    plt.ylabel("y")


x, y = sp.symbols('x y')
f = 2 - x**2 - y**2

N = 100
x_range = np.linspace(-1,1,N)
y_range = np.linspace(-1,1,N)

plot_function(f, x, y, x_range, y_range)


N = 10
x_range = np.linspace(-1,1,N)
y_range = np.linspace(-1,1,N)

plot_gradient_vector_field(f, x, y, x_range, y_range)
plt.show()

# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm


## for high resolution image
# %config InlineBackend.figure_format = 'retina'


def plot_function(f, x, y, x_range, y_range, ax=None):
    """ takes a sympy function f(x,y) and plots it over the range x_range and y_range """
    f = sp.lambdify((x, y), f, 'numpy')
    X, Y = np.meshgrid(x_range, y_range)
    Z = f(X, Y)

    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
    ax.set_title("Funktionsgraph")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_zlabel("z")
    return ax




def plot_gradient_vector_field(f, x, y, x_range, y_range):
    """ takes a sympy function f(x,y) and plots the gradient of f over the range x_range and y_range """
    X, Y = np.meshgrid(x_range, y_range)
    grad_fx, grad_fy = [sp.lambdify((x,y),f.diff(xi),"numpy") for xi in [x,y]]
    u = grad_fx(X, Y)
    v = grad_fy(X, Y)

    plt.figure()
    plt.quiver(X, Y, u, v)
    plt.title("Gradientenfeld")
    plt.xlabel("x")
    plt.ylabel("y")


x, y = sp.symbols('x y')
f = x**2 - y**2

N = 100
x_range = np.linspace(-1,1,N)
y_range = np.linspace(-1,1,N)

plot_function(f, x, y, x_range, y_range)


N = 10
x_range = np.linspace(-1,1,N)
y_range = np.linspace(-1,1,N)

plot_gradient_vector_field(f, x, y, x_range, y_range)
plt.show()

# %%
x, y = sp.symbols('x y')
f = 2 - x**2 - y**2

N = 100
x_range = np.linspace(-1,1,N)
y_range = np.linspace(-1,1,N)



ax = plot_function(f, x, y, x_range, y_range)

X, Y = np.meshgrid(x_range, y_range)
ax.plot_surface(X, Y, np.ones_like(Y)*2, cmap=cm.bone)

ax.view_init(elev=15., azim=25.)
